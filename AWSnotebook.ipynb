# %% [markdown]
# ### インフラができるようになるメリット
# 1. 自分でサービスを作れる
# 1. システム全体で対応できる

# %% [markdown]
# ### インフラを構築するとは
# - サーバーの構成を考え、作成する
# - ネットワークの構成を考え、サーバーをネットワークに接続する

# %% [markdown]
# ## AWSとは
# Amazon Web ServicesはAmazon社が提供するクラウドサービス。
# 100以上のサービスが存在し世界最大級。
#
# - サービスが豊富
#     - 高負荷に耐えられる、信頼性の高いシステムを少ない手間で運用できる
# - リソースが柔軟
# - 従量課金

# %% [markdown]
# ## インフラってなに？
#
# ### インフラとは？
# ITにおいては、サーバーやネットワークの事
#
# ### サーバーとは？
# クライアントにサービスを提供するコンピュータ
# ex. webサーバー、DBサーバー
#
# ### ネットワークとは？
# 複数のコンピュータをつないで、データを送受信できるようにするもの
#     　- クラウドでサーバーやネットワークを提供するサービスがAWS
#
# ### クラウドとは？
# - オンプレミス
# > インフラを自前で用意して、自社で所有・管理すること<br>
# > 初期コストが高く、調達期間が必要
# - クラウド
# > 初期コストが少なくすぐに始めることができる。<br>
# > 費用の予測が付きづらい。<br>
# > クラウド全体で障害が起こると対応のしようがないこと。

# %% [markdown]
# ### マネジメントコンソール
# AWSの管理画面
